# %% [markdown]
# # Análise de arquivos de texto
#
# Neste mini projeto iremos aprender a realizar a leitura e uma breve análise de dados de um arquivo de texto. Embora o arquivo dicionário tenha mais de 10 milhões de termos (que incluem palavras com prefixos e sufixos e siglas), como o tamanho do dicionário era do ordem de várias dezenas de megabytes, resolvi extrair uma amostra aleatória desses termos, obtendo um arquivo com mais de 10.000 linhas e aproximadamente 20Kb de tamanho apenas.

# %% [markdown]
# Primeiramente vamos construir algumas variáveis auxiliares:

# %%
nome_arquivo = 'amostra-palavras.txt'
diretorio_arquivo = '../dados/'
caminho_arquivo = diretorio_arquivo + nome_arquivo

# %% [markdown]
# Em seguida vamos abrir o arquivo em modo de leitura apenas.

# %%
arquivo = open(caminho_arquivo, mode = 'r')  # mode = 'r' é o argumento padrão, não precisava ter sido incluido.

# %% [markdown]
# Lendo uma linha:

# %%
arquivo.readline()
# Out:
# 'adeusarmos\n'

# %%
# Lendo de novo:
arquivo.readline()
# Out:
# 'desrelvaste\n'

# %% [markdown]
# O que aconteceu? Acabamos de invocar o método readline() de arquivo duas vezes e obtivemos resultados diferentes!
#
# **Exercício 1**: Abra o arquivo 'amostra-palavras.txt' usando um editor de texto simples (Notepad no Windows, p. ex.) e faça uma hipótese sobre o que ocorreu.
#
# Não siga em frente sem realizar esta tarefa, discuta com seus colegas, se preciso pesquise na internet.
#
# ---

# %% [markdown]
# ## Stream Ponteiro de arquivo.
# Veja o código abaixo:

# %%
arquivo.seek(0)
arquivo.readline()
# Out:
# 'adeusarmos\n'

# %% [markdown]
# Um objeto de arquivo possui um cursor (`stream` em inglês) que indica a posição de leitura/escrita atual do arquivo. Note que a cada chamada do método `readline()` o stream avança uma linha.
# Quando o método de arquivo `seek()` é invocado com o argumento `0` ele muda a posição do cursor para o início do arquivo (o valor 1 mantém na posição atual e 2 desloca para o final). Vamos retirar  os caracteres de controle ds strings:

# %%
arquivo.readline()
# Out:
# 'pinheiro-insigne\n'

# %% [markdown]
# ---
# ## Limpeza de dados
#
# Limpando a entrada com o método `strip()`.

# %%
linha = arquivo.readline()
linha
# Out:
# 'encoimamo-lo\n'

# %%
linha = linha.strip()
linha
# Out:
# 'encoimamo-lo'

# %% [markdown]
# ---
# ## Um pouco de análise

# %% [markdown]
# Agora vamos imprimir uma amostra de `n` linhas (vc define quantas linhas quer ver mudando a variável  `n`).

# %%
n = 10
for i in range(n):
    linha = arquivo.readline()
    print(i, linha.strip())
# Out:
# 0 companhareis
# 1 enchavetassem-me
# 2 esbamboaram-lhe
# 3 gebando-as
# 4 acotonada
# 5 latimo-lo
# 6 saltei-lhe
# 7 achoar-vos
# 8 agératos
# 9 escarguemos-te

# %% [markdown]
# Agora vamos imprimir todas as linhas do arquivo. Preste atenção na sintaxe, ela é diferente da sintaxe acima. Dependendo da interface utilizada, vc ficará com uma saída gigantesca no Jupyter Notebook.

# %%
arquivo.seek(0)
for linha in arquivo:
    print(linha, end='')
# Out:
# adeusarmos
# desrelvaste
# hiperorganizá-la-iam
# pinheiro-insigne
# afinhar-vos-ás
# vibrar-vos-ia
# contrafortar-te-ia
# encoimamo-lo
# dessoldá-los-emos
# pleiteara-o
# superlotei
# braceado-se
# colchetarem-lhes
# tangava-lhe
# conglobai-te
# seguemos-te
# desenfarda
# ultradimensionei-as
# açalmadorazinhas
# asseveravam-nas
# emboldriando-te
# desenrugaá-la-á
# endoudecesse-o
# esgaço-vos
# derrelhe-se-lhes
# deslabializavam-lhes
# febrilíssimo
# enlapávamo-vos
# companhareis
# enchavetassem-me
# esbamboaram-lhe
# gebando-as
# acotonada
# latimo-lo
# saltei-lhe
# achoar-vos
# agératos
# escarguemos-te
# assim-assim
# do
# panegirizado-as
# ressegundavam-na
# sugilaram-se
# fodamo-nos
# concordarmo-la
# turtuveei-lhe
# jalapãozinho
# fobite-os
# injuriadorazinhas
# deletrear-se-ia
# engaliadão
# ovacionai-nos
# desengajavam-vos
# suplicá-los-emos
# esborrachara-me
# apompem-lhes
# abarrilhado-nos
# embuçalando-me
# aferar-me-ei
# espavitam-lhe
# arrendondavam-lhes
# engaravitam-se-lhes
# carcacharem-na
# desconstranger-te-ia
# morfodiferenciem-vos
# endoudara-o
# rebuliam-me
# eticizar-lha
# pandemizaram-lhes
# coltarem-vos
# esfuriá-las-emos
# entronquecer-lhes-ias
# dependurando-vos
# abregoai-a
# abscedeste-se
# espamparem-no
# endentecer-vos-ás
# esplendescera-os
# reusar-lhes-ei
# sobre-entender-nos-ei
# desencavalgar-vos-ia
# enchavete-se-lhes
# desempolgaste-os
# culcai-as
# aridifico-me
# adua-las-á
# contra-anunciar-lhe-iam
# soluço-lhe
# ressolhem-lhe
# esgueirá-lo-ei
# acorrentássemos
# refortificava-vos
# entuchar-nos-ás
# abiqueirara-lhe
# enfervecera-os
# apense-os
# reescravizar-te-emos
# dramatizai
# chonar-vos
# rilaram-lhes
# reencafuou-vos
# acinturasse-se-lhes
# emetizassem-se
# encovilei-as
# deslastrasse-vos
# galreaste-nos
# azaburros
# cravou
# fisiologizarmos
# cresci-lhes
# ex-PSDC-RR
# criminaram
# incrisasse-as
# enrodilhadorzão
# reflexionamos-lhe
# subnutrira-me
# padecer-me-ás
# esbeirasse-lhe
# gosmasse-vos
# marmelas-nos
# paraboloidalidade
# autocorológico
# mancomunado-o
# surpreender-lhe-ão
# empasmara-as
# imparcializo-a
# excomunhem-vos
# enfarais
# triangularíamos
# desempolgassem-lhe
# batocariam
# espojinhava-se-lhe
# desmassajar-te-ia
# adonairo-te
# esporteiraste-lhe
# desincubar-me-iam
# esteticizei-o
# nefrografia
# amarlotemos
# metamorfoseei-te
# enlouçara-se-lhe
# dealbado-se-lhes
# embandar-nos-iam
# apeanhassem
# milpartamo-vos
# cuieté
# didimodínica
# fraturarás
# emedoiçava-te
# instalaram
# baldoado-a
# amarilígenas
# academicizaríamo-vos
# rompantosas
# emagotamo-vos
# criocauteriza-lhe
# cascarrearmo-vos
# estaleirara-os
# miqueia-se
# acarinhaste-as
# importune-lhes
# encaixarmos-te
# decorticásseis
# foder-te-ia
# desencrespadões
# escadeia-te
# moqueteadoramente
# abarreiramo-los
# coadjuvou-se
# engalia
# pipocavam-lhe
# escurejam-se-lhes
# empaliares
# paquimetópons
# escabrarei
# charutanga
# acachoeirar-lhe-ás
# sota-venteado-se
# esmanjara-se-lhes
# reinaugurar-no-ão
# conglomerara-vos
# espaçar-lhe-ei
# septou-me
# reconstitucionalizaste-lhes
# impregnara-a
# ionômera
# deslajeásseis
# desaconchegávamos-lhes
# messarem-se-lhes
# minerar-lhes-ia
# polmeara-te
# desenfronhemo-las
# descapitalizar-vos-ias
# desautorizavam-se-lhe
# encaudarás
# fotometrar-se-lhes
# resseles
# deslaudou-os
# paranasalidade
# reacoplá-lo-iam
# abobecharam-se
# uivaste-se-lhe
# neurodocitinhos
# enxamear-lhe-iam
# descavaste-me
# escaliçadorona
# molificávamo-la
# tressaltar-vos-á
# interjeicionado-me
# siado-se
# descraveiramos
# cavumbulares
# fraseadamente
# betuminizar-me-iam
# reguinchasse-vos
# acionei-as
# anticomplementarem-lhe
# anglomanizem-te
# aganeando-me
# acaudataste-nos
# estravara-lhes
# sabatizava-se
# arredolei-o
# CRM-AC
# amornai-se
# rebatá-lo-ia
# debacaste
# surucávamo-lo
# encolherdes
# discando-nos
# avalentoamos-lhe
# desenrouquecendo-te
# Camacupa
# virtualizem-se
# esquentei-os
# encataplasmáramos
# sobrecabei-as
# pielografar-vos-ias
# reemigram-vos
# autonivelasse-me
# mourejas-lhe
# desembuçar
# exorcismem-vos
# reavivassem-na
# coudecê-los-emos
# refolegado-me
# subfretemo-vos
# amourôo-o
# fleborreografia
# salinar-nas-ão
# troçar-me-ia
# camonizarem
# desatentar-me-ias
# badariano
# espremendo-vos
# contrarrespondei-o
# apocopávamo-los
# componencialissimamente
# Islands-Ilha
# desconciliado-te
# descabreásseis
# astronavalíssimas
# empiorarem-me
# desgostando-me
# avergoaremo
# passejarmo-la
# suestar-te-ia
# apinhoassem-lhe
# despearíamo-vos
# abrenhas-vos
# crimpado-as
# desempavesa-nos
# abacinar-lhe-ão
# agrado-se-lhe
# atravincava-te
# descasulaste-se-lhe
# agrilaste-lhes
# abatumar-nos-ei
# emborrascar-te
# jeremiasse-se
# silogizávamos-lhes
# coisificá-la-ei
# cheiretei-te
# enformoseaste-o
# pelintraras
# acumular-se-lhe
# antedatado
# celebremos-lhes
# antecríticas
# oviniologística
# emparvoecermo-los
# microcircular-se-lhes
# parvoejantes
# tozalinonas
# amedalhassem-vos
# fortificam-no
# abaquiar-nos-iam
# exemplarizavelmente
# ginasticar-se-iam
# sudorificai-te
# efundidoronas
# achamegar-lhes-emos
# dejarretá-los-emos
# bromou-vos
# ecolocalizarem-lhes
# mixa-me
# semiagregado-nos
# desfascistizaste
# sequenciante
# ausentasse-lhes
# deslegassem-nas
# pospontado
# encampar-se-iam
# araviar-lha
# autosserrilhasse-a
# papoucaria
# alistas-se
# amerceasse-lhes
# malinai-nos
# acidaminá-las-ei
# desconscientize-se
# paravivianite
# desconstruíamos-lhes
# maximizavam-te
# javradoronas
# pelidásseis
# monosseriado
# chichelei-me
# interestratificá-la-ei
# cheiricaram-vos
# escrofularizavam-no
# desgenitalizado-se-lhe
# descomovi-las-emos
# rejulgam-lhe
# engastoemo-las
# reportando-lhes
# mimique-os
# enouriçassem-nos
# varram-nas
# pandilhe-a
# tralhastes
# reemigre-te
# acendeiam-se
# acanalar-lhe-á
# esgarabulharam-no
# academiarias
# ratificadinho
# hipotrofiavam-se
# obstaculizávamo-los
# embarranque-se-lhes
# galopar-se-ás
# esmarridoras
# envidraçá-las-ei
# marulhados
# cabulei-as
# remapeasse-me
# refuste-te
# acabrunhai-o
# aguerrir-se-lhe
# extradicionaremos
# transporemos
# ruflara-o
# aquadreladíssimas
# industrializar-se-ias
# esplandecem-lhes
# borborinharei
# eutrofizar-vos-emos
# adormidos
# antemurou-os
# formigando-lhes
# altigrasnávamo-nos
# emanhuçaste-vos
# mutagenicidadas
# batourasse-as
# lampreei-a
# acetinam
# afalcaçai-nos
# assenzalassem-lhes
# recedeste-os
# gracitaram-no
# retranscrevido-a
# ensogar-se-lhe
# encorriaram-se-lhe
# citicolinas
# pipoquear-te-ão
# enfrascado-se
# desionizemo-los
# escoucinhar-lhes-ia
# sorrabam-vos
# dactilografei-vos
# gugluejar-te-iam
# cainçando-lhes
# iodando-te
# reformatasse-o
# ablaqueci-lhes
# despreocupadões
# desalarmarem-vos
# recoutaram-lhe
# sincerizarmo-la
# desmanivasse-os
# bordear-me-ei
# demulciríamo-vos
# abarrocáreis
# gripasse-lhe
# embarbelarem-nos
# monçonismos
# acasquilhá-los
# desbordá-la-emos
# desvitalizamo-las
# burgá-la-emos
# multicaule
# desembaulem-se-lhes
# semiafirmaçona
# carpintejar-me-ei
# desfraldarem-na
# urólogas
# fantasiada
# farfalhejemo
# envesadíssimas
# proctatrésica
# supraexcitou-lhe
# colorando-lhes
# rearrumassem-se-lhe
# manja-se-lhes
# acambaiem
# migmatizou-o
# esplainassem-nas
# adunquei-te
# neocolonizávamos-lhes
# agradecia-te
# garnam-te
# ematilhá-la-ia
# oxitonizando-vos
# convizinhar-te-emos
# encapotar-nos
# enfareei-me
# rechupara-a
# deródimos
# sorrissem-nos
# caloteaste-o
# bastardeando
# cinchonizar-lhes-ia
# empolamaríamo-nos
# degasá
# vernalizar-me-ias
# afoca-la-á
# espoldrinharam-lhe
# reajustas-lhe
# cravinhosinha
# acareavas
# piranga-saíra
# autoconhecer-nos
# soutar-vos-emos
# fracionava-o
# ressaibo-me
# prediga-o
# crimpaste-os
# realugar-vos-iam
# seciassem-te
# glicuronizarem-me
# sarrabiscam-nos
# deschancelaram-no
# empoou-o
# viageavam-te
# sobressolavam-no
# aborrascastes
# descondensaste-as
# ondávamos-lhes
# desjejuou-as
# admoniam-te
# abochechados
# agotar-te
# belecaste-o
# desencarapuçava-o
# debrue
# elucubrem-se-lhes
# argirântemo
# seivasse-o
# instaurar-se-ão
# descivilizaçona
# pautarei
# estoçávamo-lo
# arretamo-las
# faturá-los-emos
# hipogâmicas
# desfeia-o
# enruminai-as
# reescravizações
# encapelas-se
# tormentasse-se
# desvezasse-te
# achabaçar-me-ás
# desenclavinhou-se-lhes
# esboiçar-lha
# estrigi
# desimobilizaríeis
# arroleirar
# agoniávamos
# aristocratizemo-vos
# barranhara
# encatrafiado-se-lhes
# purganteei
# encalistrai-me
# afeminei-vos
# epilogou
# encimalhar-na-ão
# abelhoasse-lhes
# esborraçarem-te
# desentropilhar-lhes-ão
# falucávamos-lhes
# enchiçara-los-á
# insoniara-se-lhes
# discretizaram-nos
# pinoteemos-lhes
# retrasladaste-a
# catarmo-nos
# esquivassem-nos
# retroalimentamo-vos
# subpujassem-na
# invulgado
# entelheirassem-te
# desremediar-me-ás
# rebelamento
# manguearem-no
# avexamos-lhes
# chimarritas-balõezinhos
# esplendeceríamo-vos
# sussurrá-las-ei
# desmantelou-te
# encistou-vos
# empauapica-los-ás
# generosíssimo
# besoirasse-nos
# celucloralidades
# emoitasse-se-lhe
# cacite
# mancolitar-te-ás
# desquamá-la-ia
# cornificou-nos
# iniciar-te-emos
# epigrafássemos
# esfolio-lhes
# suplicaram-se-lhe
# adaptar-vos-ias
# rechupadamente
# edil
# albercadinhas
# timbrassem-se-lhe
# despontar-se-ei
# abstrativar-nos-ão
# superbronzeá-la
# iodetemo-la
# encaminha-se-lhe
# embebe-a
# autoglorifica-las-á
# abatocamento
# flertardes
# abracaríamos-te
# afolozara-se-lhes
# aperfilhá-la-ia
# barbatávamo-las
# desafundar-vos-ia
# patroar-nos-iam
# ordinarotes
# iodetando-lhes
# enfuniscar-lhos
# glaciomarinho
# mexericar-se-ia
# saguatear-no-ão
# cabrucar-vos-ei
# agrimamo-lo
# esquistificam-na
# alborcando-se-lhe
# vicia-lo-ás
# chalaceá-me
# interditar-se-ias
# arrelamparem-nas
# ambiarem-se-lhe
# peixotense
# conversalha
# trissectar-lhe-ias
# destrinçá-los-emos
# citolisemo
# reinvadiríeis
# diesar-se-lhe
# acangaceirar-se-ão
# aniquilaram-no
# entuchado-nos
# readaptarmos-te
# despurificaríamos-lhe
# monopolizara-se-lhe
# estiletizava-se
# sepulcrara
# obrigá-lo
# desencaixassem-nas
# telerradiografo-vos
# alcoforemos-te
# alfanavam-vos
# albercou-os
# abacaxis-silvestres
# alugar-lhe-iam
# espaventávamo-las
# semiajusta
# sulfatizarem-na
# refermentaste-se
# alcateando-me
# rolantear-te-ei
# entolhar-se-ás
# sabrecara-os
# aristotelizarem-me
# inflacionai-a
# emborrascastes
# entoiceirar-nos-emos
# hipofosfito
# familiarizávamos-lhe
# centétidas
# doudivanamo-la
# engrunhava-vos
# chegávamos-te
# assetearam-no
# derrelhado-me
# apiançando-vos
# predestinava-me
# vassoure-se-lhe
# coinquinabilíssimas
# repavimentarem-se-lhe
# embolorecê-lo-á
# desenxabem-na
# esfogueirar-se-ia
# retaque-vos
# emenagograficamente
# mobilizassem-se-lhe
# espeloteai-vos
# desipotecadonas
# desinternacionalizem-na
# empadrôo-os
# retirem-te
# abradar-se-lhe
# encargar-lhes-ia
# desentoaste-te
# alfandegadão
# desencangadinhos
# esquadrinhará
# alunitizaste-me
# regateie-nos
# agadanhamento
# encostava-o
# compugnaríamo-vos
# timpanizamos-lhes
# penitenciamento
# desmedular-lhes-ei
# hidroplâncton
# escarmentar-me-ei
# abifá-la
# ineri-las
# forraste-os
# dezincifiquem-se
# melitonianas
# despecuniadíssimo
# latejadorezões
# emiglitatos
# tenazá-la
# tropear-me
# rechiara-nos
# cinemizar-lhe-ias
# ferretarmo-lo
# dizimar-lhe-emos
# despressurizava-lhe
# outávamos-lhes
# mendelssohnístico
# esteticize-o
# enchumaçado-se
# hiperabsorvê-los-ei
# floraminas
# espumarejarmo-lo
# metacromáticos
# enqueriu-te
# clinquerizaste-lhes
# esmaiarem-se
# achasso-o
# voltijarem-lhes
# encaramone-me
# finfai-se-lhes
# alfanjai
# apicha-lo-ás
# atesadão
# fiambreiros
# excelendo-as
# desacreditamento
# subconscientizar-lhas
# tropeavam-nas
# passamanar-vos-ei
# entremostrei-os
# sorovacinavas
# estaze-se-lhes
# pirilampear-te-ia
# impropriar-lhe-emos
# impassibilizá-la-emos
# apandá-lo
# pelúcidas
# dessoterra-te
# cumpliciadões
# embagaram-te
# modelizadinho
# enroscavam-vos
# vitelidutos
# edulcorassem-se
# desencaminhá-la-iam
# virgulavam-lhe
# enjoujasse-lhe
# litigando-lhes
# contiguasse-se
# moucado-lhe
# repanhar-nas-ão
# contubernemo-los
# mijam-nas
# abiomba-las-ás
# pré-aprovemos-lhes
# desculturalizando-a
# hominizaram-no
# bitolar-lhe-ás
# profalçar-me-ás
# calcinai-se
# aflautara-nos
# desconvir-lhes-ia
# bonsear-vos-ia
# linfatizar-se-ei
# reeditá-lo-ei
# superou-te
# brochamento
# biodegradando-te
# desbroasse-se
# desbuchantes
# gruísse-as
# digestimo-las
# eminhocar-me-ás
# subimaginalzões
# chisparam-vos
# engabrichávamos-te
# alicerceara-a
# excursionassem-se
# gloterassem-te
# calcetai-me
# angulou-vos
# quintuplicaram-no
# maxixa-lo-á
# hausmanizas-se-lhes
# deitado-me
# arensava-lhes
# recrestasse-lhes
# sobre-encantadíssima
# encalburdando-lhes
# pentelhadonas
# engrimponaste-te
# agarrotados
# adura-nos
# superorganizaríamo-vos
# halogenoderivara-as
# desenfocar-se
# PSTU-MA
# contraprotestaremo
# chamegamento
# hiperabsorver-lhe-á
# fervelhá-la
# encascando-lhe
# orfanar-te-ias
# injustiçadíssimos
# gaiatadíssimas
# formilhado-se-lhe
# agomitai-se-lhes
# circinem-se
# tutuveara-nos
# parturira-lhes
# ejectadíssima
# pronominaliza-vos
# encortiçam
# ressorver-vos-ia
# aligeiravam-me
# intelecionar-lhes-ei
# assaltando-as
# ortogonalizarem-se
# engrosse-vos
# magiou-o
# optaçãozinha
# madracem-lhes
# desespiritualizavam-se-lhe
# desfalcoar-se-lhe
# frulhei-lhes
# aditem
# esquerdizai-os
# autolamentar-me
# superabundassem-me
# desencartava-se-lhes
# ritornelei-lhe
# caramelizar-se-lhe
# rendibilizara-te
# desempecilhassem-se
# estricninizante
# avaluassem-lhes
# exurbanizares
# enloirecêramos
# retivéramos
# esbatido-nos
# sisando-se-lhe
# agarrunchamo-lo
# unué-bolina
# desempenhar-vos-á
# jornalisticá-las-ia
# roucemos
# rimbombá-la-ei
# corioplastias
# pedantizareis
# iliocaudalismo
# choreceram-se
# esborrifar-lhes-ias
# encraveirado-lhes
# raciocinar-no-ão
# desatemorizei-vos
# reatestas-lhes
# resinificá-lo-emos
# probidosamente
# ajuntarias
# mediatizá-lo-ei
# brincalhotar-vos
# Portel-Pará/Ý
# envalecei-lhe
# frasistas
# remalinhar-te
# manquecendo-se-lhes
# castelita
# evolveu-a
# desfoliá-lo-iam
# sublimar-nos-ão
# matracados
# acabidar-nas-ão
# finco-te
# doutorar-se
# enateirem-na
# espernegamo-nos
# emparrar-nos-ei
# Jordânia-Guiné-Bissau
# desentumescê-la-emos
# embarbecê-las
# saldanheias
# revalidá-la
# aldolizara-o
# assazonarás
# gralheava-lhe
# acovatar-vos-ia
# cocociense
# ralava-a
# reganhemo-lo
# colectou-me
# migaá-las-á
# descocado-lhes
# reflutuasse-me
# amachorrado-as
# cinchamo-vos
# eleia-a
# indianizar-nos-ás
# desembruscassem-lhe
# desenqueixá-los
# freiradoronas
# desaçaimassem-nas
# gasalhosa
# quinta-colunístico
# desconturbarem-lhe
# lusmo-nos
# abarateávamos-lhes
# plano-polariza-te
# acobertadorezinhos
# lagrimejem-se-lhes
# desampara-lhes
# enfureça-os
# abairreirava-nos
# adnumera-lo-ás
# encarteirai-as
# heroifique-lhes
# hiperexploradinhos
# industriar-lhes
# espavorizava-se-lhe
# envidasse-me
# amoirisque-nos
# escopeteai-te
# acardumarmo
# curseantes
# fortunássemos
# formigueavam-na
# emparvoaram-se-lhes
# interpenetram-no
# Altivirezinhos
# recusando-vos
# desencasar-lhes
# envaidam-lhe
# afrentar-lhes-ia
# embocareis
# recedia-nos
# desvascularizamo-las
# perpetuem-na
# despacientar-nas-ão
# aberlinar-se-ei
# encofraríamos-lhe
# aconapar-lhes-ia
# estiraçam-na
# desentrosadorzão
# injerizavam-te
# desembauladora
# cumpliciava-te
# revelidorezões
# cilhava-lhes
# metabolizava-te
# desacismai-se
# experimento-me
# desemparíamo-nos
# desencambaram-vos
# exsolva-a
# calemburam
# estugue-se
# embaratecido-o
# galardoar-te-ias
# achoiriçou-vos
# ladramo-la
# sumariar-vos-emos
# retaliavas
# avoluma-a
# culhãozinho
# desempinassem-vos
# tradicionalizadíssimo
# agradecer-lhes-emos
# apaixoná-la
# desladrilhou-me
# rastolha-o
# empanturrou-se-lhe
# alveitasse-lhe
# golfou-lhes
# recompensasses
# deixa-se-lhes
# ameaços
# esbramem-nas
# despudoradíssimo
# maldir-lhes-ei
# conomeassem-vos
# ouro-pigmento
# reinventarei
# bipolarizem-lhe
# desacunhar-se-ão
# cinzelar-se-ei
# desimaginando-o
# humanizam-na
# cincam
# alfanjei-o
# haraganado-os
# encauchá-la-ei
# textualizam-vos
# galiciparlá-la-emos
# pautar-nos-ia
# desassociaram-te
# desarrotes
# pregavas
# apologizas-nos
# jambeiros-aguados
# favoniamo-la
# depredarem-te
# belisquem-vos
# embutisse-se
# desfalecer-me-ei
# berrá-la-iam
# fervia-os
# relentemos-lhes
# desenclaustrara
# nanópodes
# destacou-lhes
# desidrata-lo-á
# hispado-se-lhe
# incarnai-o
# prioraste-te
# rafinam-se
# abordem-se-lhes
# basteirear-me-ão
# afarolava-o
# sobredensamente
# desmemoriarmo-los
# desemudecendo-se-lhe
# descoruchemos
# amoutar-lhe-á
# nematogônio
# ariscassem-me
# caotizar-te-ias
# conchegabilíssimo
# tachonar-me-ei
# emedoichassem-lhes
# desestribo-as
# espertiná-las-ia
# avozeirando-vos
# anomeávamos-lhes
# recordem-vos
# embretar-nos-ás
# espadara-se-lhes
# infincasse-a
# lobreguejar-lhos
# bochar-se-ão
# admonamo-nos
# acanoar-lhe-á
# escatolize-os
# eugenizam-se-lhe
# sigilam-me
# reinvadia-os
# boquejados
# batiiperestético
# Dominicana-Bermudas
# jure-se-lhe
# quantificadíssimas
# paurometabolizá-la-emos
# dessamoucava-a
# autosporulemos-te
# arrobar-lhe-á
# escanhote-lhes
# encapele-a
# gladiaste-nos
# audiovisualizar-me-á
# abaulava-me
# securitizaríamo-nos
# fairavam-nas
# furfunhem-te
# desencoivaram-nos
# seitosinho
# desemburrado-a
# entressorrira-vos
# subentendidinhos
# conchegues
# quaresmasses
# paramilitarizado-me
# destravancavam-na
# artificializasse-se
# assuntar-nos-ão
# repudiou-lhes
# ladrejaste
# cantarejava-lhe
# emplanchasse-os
# averdunguei-lhes
# arimã
# entrefizera-te
# empombara-nos
# esbalda-los-á
# encapadorona
# emadeirem
# borraçáreis
# entintares
# gostando-vos
# cacu
# desmortalhar-vos-ei
# consogram-no
# cauchutam-lhes
# superaprove-se-lhe
# alapavam-se-lhe
# perlongar-vos-ia
# vasculhar-nos-emos
# ampliar-me-ias
# inane-as
# guaiá-los
# epigínicas
# desempegadorzinho
# anuviar-nos-iam
# televisar-na-ão
# alinguetara-te
# superotimize-a
# coorientem-nos
# texturizai-te
# descapotávamos-lhes
# apatrulharem-se-lhe
# desamurarem-lhes
# deslapem-se
# moquamo-nos
# pareemos-te
# fangarelados
# borcasse-se-lhes
# desempalem-vos
# brassícica
# escabujar-lhe-ás
# pré-excluía-lhe
# enrestarem-no
# apiabassem-lhes
# lourávamo-los
# descimbrar-nos-á
# amelindrarmo-los
# desconsentissem-se-lhe
# exorcismaste-nos
# cancromíneos
# Ocidental-Guernsey
# decorticar-nos
# trapacha-se-lhes
# desengraçasse-se-lhe
# escolhesse-lhes
# acumplicie
# esboiçaram-se-lhes
# reinfectas-lhes
# anoitecem-se
# explicitou-a
# recortasse-lhe
# desencapsular-vos-ia
# oitavando-as
# desmarchetar-me-ás
# aromatizar-te-ias
# aripiar-no-ão
# agrego-a
# descerebrizarmo-vos
# aparacera-me
# alumbrar-me
# superimpregnas-vos
# extradiciones
# emparedou-vos
# saraqueime-lhe
# mansupiam-lhes
# pinimbar-lhe
# trejeiteado-me
# pagodearam
# emparveçam-no
# emaciamo-lo
# enxalmava-nos
# festôo-lhe
# estremecei-te
# Parobé-RS
# malgovernou-a
# lupangos
# coadunávamo-la
# ateizações
# placida-as
# chefiar-se-lhe
# lincha-o
# enrizado
# afrissuramo-los
# emolhavam-lhe
# entouceiram-na
# borborinhar-vos-ia
# abotecar-te-ás
# unguífero
# badeleadas
# escanhotemo
# rinchando-as
# aparatávamo-lo
# contraprovar-lhe-ão
# cisai-os
# grilhetar-lhas
# papoulais
# goive-os
# charrisca-lhe
# amarrotava-os
# emboba-se
# soleei-lhe
# desinvernadoramente
# inquestionabilíssimo
# decemparti-lo-ei
# tragediar-vos-ás
# arresinava-lhes
# desencoscorar-se-ás
# resplendamos-te
# penujá-la-ei
# debava-o
# destoitiçávamos-lhe
# acochichar-te-á
# amigadas
# desencalharas
# ejacularmos-lhe
# armar-lhes-á
# ultrafiltraste-me
# coassociarei
# abençoemos-lhes
# escurejassem-nas
# aforciarão
# estabilitar-se-á
# toluizasse
# alimpasse-me
# encarvoar-nos-ás
# moveltipriizinhos
# reasfaltem-me
# sufixarem-me
# carripotos
# desempadralhassem-vos
# exsuemo-nos
# amatalarem-se-lhes
# pré-insiram
# anemiada
# competiam-se
# caneia-se
# estaferme-lhes
# avelhá-lo
# flexionadoramente
# turvasse-o
# acampávamo-lo
# endomingar-me-iam
# opalinizar-te-ei
# desempavesara-as
# alambazara-te
# desafaimar-na-ão
# apoftegmático
# mexelhadoramente
# enchaveto-me
# estiletizadorazinha
# epistolizavas
# apavesar-nos-iam
# pedantocracia
# galampeio-vos
# envidraçam-se
# flaflar-se-iam
# escamalhei-lhes
# cheiretadíssimo
# antipopulasse-vos
# entijucaram-te
# remonotonizas-lhes
# desapaixonam-me
# igualhar-lhe-ias
# empolháramos
# sifonarmo-la
# alorcinatismos
# detençar-na-ão
# enguiçamo-vos
# aleluiando-nos
# atericiar-vos-ás
# afigurassem-me
# manhentadoramente
# conselhasse-vos
# abcedável
# abuçara-lhe
# suberifica-las-ás
# desbarrigado-as
# gaivoteamos-lhe
# repastar-lhes-ias
# alinhavadeiras
# bamboleiam
# contrarraciocinaram-nos
# desenraivecessem
# cincunscrever-lhe-iam
# possei-te
# pelaras
# anegrar-me-iam
# incrementá-lo-emos
# coocupadonas
# arreçoar-lhes-iam
# bandar-lhes-emos
# desempalmam-na
# adentrar-se-lhes
# desalijaste-os
# desensurraste-me
# copidescabilíssimo
# agotar-nos-ás
# engigadorazinha
# atermam-no
# amandava-nos
# crisolou-as
# desanichávamo-lo
# empacotará
# radiodermitinho
# lenhar-me-iam
# recepcionaste-as
# liberavam-se-lhes
# sufragam-na
# tutassem
# albidaste-os
# trombaste-a
# apaixonarem-na
# entreamadíssimo
# coinicias-nos
# estambrá-lo-ia
# ensurroando-se
# desmanivamo-la
# digredistes
# distancio
# teletransmitir-te-ias
# adverbavam-se-lhe
# desemedado-te
# desamuai-se-lhes
# acompassaram-te
# desassinalar-se-lhes
# desempoleemos-te
# impessoalizaram-no
# estopando-vos
# embiocaram-no
# manocar-nos-ias
# aracnizem-se-lhe
# vale-varguense
# lampejar-te-ei
# reabsorvi-la-emos
# entenebremo-los
# encristavam-lhes
# bordara-te
# circunvemo-vos
# aterrizaras

# %% [markdown]
# ---
# ## Exemplos

# %% [markdown]
# **Exemplo 1**: contar quantos caracteres aparecem em um arquivo (sem contar os caracteres de controle).

# %%
arquivo.seek(0)
n = 0
for linha in arquivo:
    linha = linha.strip()
    n = n + len(linha)

print(n)
# Out:
# 17922

# %% [markdown]
# **Exemplo 2**: contar quantas vezes um caracter aparece em um arquivo.

# %%
caracter = 'c'
arquivo.seek(0)
nc = 0
for linha in arquivo: 
    linha = linha.strip()
    for letra in linha:
        if letra == caracter:
            nc = nc + 1

print(n, nc, nc/n*100)
# Out:
# 17922 564 3.146970204218279

# %% [markdown]
# ## Exercícios
#
# **Exercício 2**: Faça um código que conte o número de linhas de um arquivo.
#
# **Exercício 3**: Implemente um função `conta_caracteres`, com a seguinte sintaxe:
#
# ```Python
# def conta_caracteres(arquivo, caracter):
#     ...   # aqui entra o código
#     return n  # retorna o número de vezes que caracter aparece no arquivo.
# ```

# %% [markdown]
# ---
# ## Investigando informações sobre um arquivo, antes de abrir ele, usando o módulo os.
#
# **Qual o tamanho do arquivo?**

# %%
status = os.stat(caminho_arquivo)
print('O arquivo "', nome_arquivo, '" possui ', status.st_size, ' bytes.', sep='')
# Out:
# O arquivo "amostra-palavras.txt" possui 19535 bytes.

# %%
arquivo.readline()
